# %%
import pandas as pd

df = pd.read_csv('results/asco_articles_with_company_human_edited.csv')

df.head()
# Out:
#                                                title  \
# 0  Adjuvant Nivolumab in High-Risk Muscle-Invasiv...
# 1  Impact of an Epstein-Barr Virus Serology-Based...
# 2  Single or Double Induction With 7 + 3 Containi...
# 3  Menin Inhibition With Revumenib for KMT2A-Rear...
# 4  Inotuzumab Ozogamicin and Low-Intensity Chemot...
#
#                                              authors  \
# 0  Matthew D.  Galsky; Johannes Alfred  Witjes; J...
# 1  Wen-Jie  Chen; Xia  Yu; Yu-Qiang  Lu; Ruth M. ...
# 2  Christoph  R̦llig; Bj̦rn  Steffen; Christoph...
# 3  Ghayas C.  Issa; Ibrahim  Aldoss; Michael J.  ...
# 4  Patrice  Chevallier; Thibaut  Leguay; Marc  De...
#
#                                            countries  \
# 0  NY; the Netherlands; Germany; NC; Romania; Spa...
# 1  China; China; China; China; MD; China; China; ...
# 2  Germany; Germany; Germany; Germany; Germany; G...
# 3  TX; CA; IL; MO; GA; OH; CA; PA; IA; CO; OR; th...
# 4  France; France; France; United Kingdom; Czech ...
#
#                                             abstract publication_date  \
# 0  Clinical trials frequently include multiple en...         1/1/2025
# 1  Purpose: Screening for nasopharyngeal carcinom...         1/1/2025
# 2  Purpose: To determine the optimal daunorubicin...         1/1/2025
# 3  Purpose: Revumenib, an oral, small molecule in...         1/1/2025
# 4  Purpose: The use of inotuzumab ozogamicin (InO...       12/20/2024
#
#             doi                                 author_disclosures  \
# 0  JCO.24.00340  [{'Author': 'Matthew D. Galsky', 'Disclosures'...
# 1  JCO.23.01296  [{'Author': 'Zhiwei Liu', 'Disclosures': ['Emp...
# 2  JCO.24.00235  [{'Author': 'Christoph R̦llig', 'Disclosures'...
# 3  JCO.24.00826  [{'Author': 'Ghayas C. Issa', 'Disclosures': [...
# 4  JCO.24.00490  [{'Author': 'Patrice Chevallier', 'Disclosures...
#
#             product_name          company_name  company_in_the_list
# 0              nivolumab  Bristol Myers Squibb                 True
# 1                    NaN                   NaN                False
# 2           daunorubicin                   NaN                False
# 3              revumenib                Syndax                 True
# 4  inotuzumab ozogamicin                Pfizer                 True

# %%
# for countries column, if there are two capital letters, repalce it with USA
df['countries'] = df['countries'].apply(lambda x: '; '.join(['USA' if isinstance(part.strip(), str) and len(part.strip()) == 2 and part.strip().isupper() else part.strip() 
                                                            for part in str(x).split(';')]) if isinstance(x, str) else x)

# new column named "multiple_nationality" if country >=3, and main_country with the most frequent country
df['multiple_nationality'] = df['countries'].apply(lambda x: 1 if len(set(country.strip() for country in str(x).split(';'))) > 2 else 0)
df['main_country'] = df['countries'].apply(lambda x: max(
    [country.strip() for country in str(x).split(';')], 
    key=lambda k: str(x).split(';').count(k.strip())
) if isinstance(x, str) else x)

df.head()
# Out:
#                                                title  \
# 0  Adjuvant Nivolumab in High-Risk Muscle-Invasiv...
# 1  Impact of an Epstein-Barr Virus Serology-Based...
# 2  Single or Double Induction With 7 + 3 Containi...
# 3  Menin Inhibition With Revumenib for KMT2A-Rear...
# 4  Inotuzumab Ozogamicin and Low-Intensity Chemot...
#
#                                              authors  \
# 0  Matthew D.  Galsky; Johannes Alfred  Witjes; J...
# 1  Wen-Jie  Chen; Xia  Yu; Yu-Qiang  Lu; Ruth M. ...
# 2  Christoph  R̦llig; Bj̦rn  Steffen; Christoph...
# 3  Ghayas C.  Issa; Ibrahim  Aldoss; Michael J.  ...
# 4  Patrice  Chevallier; Thibaut  Leguay; Marc  De...
#
#                                            countries  \
# 0  USA; the Netherlands; Germany; USA; Romania; S...
# 1  China; China; China; China; USA; China; China;...
# 2  Germany; Germany; Germany; Germany; Germany; G...
# 3  USA; USA; USA; USA; USA; USA; USA; USA; USA; U...
# 4  France; France; France; United Kingdom; Czech ...
#
#                                             abstract publication_date  \
# 0  Clinical trials frequently include multiple en...         1/1/2025
# 1  Purpose: Screening for nasopharyngeal carcinom...         1/1/2025
# 2  Purpose: To determine the optimal daunorubicin...         1/1/2025
# 3  Purpose: Revumenib, an oral, small molecule in...         1/1/2025
# 4  Purpose: The use of inotuzumab ozogamicin (InO...       12/20/2024
#
#             doi                                 author_disclosures  \
# 0  JCO.24.00340  [{'Author': 'Matthew D. Galsky', 'Disclosures'...
# 1  JCO.23.01296  [{'Author': 'Zhiwei Liu', 'Disclosures': ['Emp...
# 2  JCO.24.00235  [{'Author': 'Christoph R̦llig', 'Disclosures'...
# 3  JCO.24.00826  [{'Author': 'Ghayas C. Issa', 'Disclosures': [...
# 4  JCO.24.00490  [{'Author': 'Patrice Chevallier', 'Disclosures...
#
#             product_name          company_name  company_in_the_list  \
# 0              nivolumab  Bristol Myers Squibb                 True
# 1                    NaN                   NaN                False
# 2           daunorubicin                   NaN                False
# 3              revumenib                Syndax                 True
# 4  inotuzumab ozogamicin                Pfizer                 True
#
#    multiple_nationality key_country
# 0                     1         USA
# 1                     1       China
# 2                     0     Germany
# 3                     1         USA
# 4                     1      France
